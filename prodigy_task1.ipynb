# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("C:\\Users\\GAYATHRI\\OneDrive\\Documents\\sample1.csv")
print(data)
# Out:
#     Age  Gender      Name
# 0    18  female      janu
# 1    11    male      raju
# 2    56  female     radha
# 3    35    male      hari
# 4    23  female      manu
# 5    67    male     yashu
# 6    17  female    pavani
# 7     9  female   kalyani
# 8    25    male     kiran
# 9    27  female     sriya
# 10   20    male      deva
# 11   16    male    harsha
# 12   30  female    vaishu
# 13   32    male       jai
# 14   18  female      siri
# 15   11    male      ravi
# 16   56  female   keerthi
# 17   23    male    ganesh
# 18   67  female  gayathri

# %%
# Create a histogram for the age distribution
plt.figure(figsize=(8, 4))
plt.hist(data['Age'], bins=10, edgecolor='black', alpha=0.7)
plt.title('Age Distribution')
plt.xlabel('Age Groups')
plt.ylabel('Count')
plt.show()

# %%
# Create a bar chart for gender distribution
gender_counts = data['Gender'].value_counts()
plt.figure(figsize=(6, 4))
gender_counts.plot(kind='bar', color=['blue', 'pink', 'purple', 'gray'])
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()
